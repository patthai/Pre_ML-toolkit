# %%
import networkx as nx

# %%
import matplotlib.pyplot as plt

# %%
from networkx.algorithms import bipartite

# %%
G = nx.read_weighted_edgelist("input/graph.csv", delimiter=",")

# %%
G.edges(data=True)
# Out:
# [(u'non-suicidal665', u'suicidal185', {'weight': -5.0}),
#  (u'non-suicidal665', u'suicidal182', {'weight': -7.0}),
#  (u'non-suicidal665', u'suicidal183', {'weight': -15.0}),
#  (u'non-suicidal665', u'suicidal241', {'weight': -9.0}),
#  (u'non-suicidal665', u'suicidal128', {'weight': -12.0}),
#  (u'non-suicidal665', u'suicidal129', {'weight': -10.0}),
#  (u'non-suicidal665', u'suicidal240', {'weight': -18.0}),
#  (u'non-suicidal665', u'suicidal124', {'weight': -4.0}),
#  (u'non-suicidal665', u'suicidal125', {'weight': -1.0}),
#  (u'non-suicidal665', u'suicidal126', {'weight': -6.0}),
#  (u'non-suicidal665', u'suicidal127', {'weight': -10.0}),
#  (u'non-suicidal665', u'suicidal120', {'weight': -2.0}),
#  (u'non-suicidal665', u'suicidal121', {'weight': -7.0}),
#  (u'non-suicidal665', u'suicidal122', {'weight': -10.0}),
#  (u'non-suicidal665', u'suicidal123', {'weight': -15.0}),
#  (u'non-suicidal665', u'suicidal274', {'weight': -4.0}),
# ...

# %%
nx.max_weight_matching(G,  maxcardinality=True)
# Out:
# {u'non-suicidal1': u'suicidal192',
#  u'non-suicidal103': u'suicidal176',
#  u'non-suicidal108': u'suicidal93',
#  u'non-suicidal110': u'suicidal284',
#  u'non-suicidal111': u'suicidal24',
#  u'non-suicidal112': u'suicidal137',
#  u'non-suicidal113': u'suicidal37',
#  u'non-suicidal114': u'suicidal13',
#  u'non-suicidal115': u'suicidal98',
#  u'non-suicidal117': u'suicidal46',
#  u'non-suicidal118': u'suicidal26',
#  u'non-suicidal119': u'suicidal3',
#  u'non-suicidal124': u'suicidal306',
#  u'non-suicidal129': u'suicidal229',
#  u'non-suicidal130': u'suicidal230',
#  u'non-suicidal132': u'suicidal250',
#  u'non-suicidal135': u'suicidal269',
#  u'non-suicidal136': u'suicidal221',
#  u'non-suicidal138': u'suicidal307',
#  u'non-suicidal140': u'suicidal242',
#  u'non-suicidal141': u'suicidal243',
#  u'non-suicidal142': u'suicidal252',
#  u'non-suicidal143': u'suicidal258',
#  u'non-suicidal144': u'suicidal80',
#  u'non-suicidal145': u'suicidal245',
# ...
